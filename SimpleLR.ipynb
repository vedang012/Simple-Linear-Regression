# %% [markdown]
# <a href="https://colab.research.google.com/github/vedang012/Simple-Linear-Regression/blob/main/SimpleLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('cgpa')
plt.ylabel('package in lpa')
plt.show()

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, 1:2]

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
y
# Out:
#      package
# 0       3.26
# 1       1.98
# 2       3.25
# 3       3.67
# 4       3.57
# ..       ...
# 195     2.46
# 196     2.57
# 197     3.24
# 198     3.96
# 199     2.33
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
X_test.head()
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57

# %%
y_test.head()
# Out:
#      package
# 112     4.10
# 29      3.49
# 182     2.08
# 199     2.33
# 193     1.94

# %%
X_test.iloc[0].values.reshape(1,1)
# Out:
# array([[8.58]])

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[3.89111601]])

# %%
plt.scatter(df['cgpa'], df['package'])
plt.plot(X_train, lr.predict(X_train), color='red')
plt.xlabel('cgpa')
plt.ylabel('package in lpa')
plt.show()

# %%
lr.coef_ # this is m value (slope) in y = mx + b
# Out:
# array([[0.55795197]])

# %%
lr.intercept_ # this is b (y-intercept) in y = mx + b
# Out:
# array([-0.89611192])
